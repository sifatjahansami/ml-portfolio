# %% [markdown]
# <a href="https://colab.research.google.com/github/sifatjahansami/ml-portfolio/blob/main/day1_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-08e5af76-b207-438b-b2fd-7f9585568cb3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08e5af76-b207-438b-b2fd-7f9585568cb3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("ME2212.csv")
df.head()
# Out:
#   ME2212 Unnamed: 1 Unnamed: 2   Unnamed: 3
# 0   Time      Force     Stress       Strain
# 1    sec          N      N/mm2            %
# 2      0       5.16  0.1285132            0
# 3   0.05     47.592    1.18531  0.007466666
# 4    0.1    132.681   3.304507   0.01485185

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("ME2212.csv")
print(df.head())
# Out:
#   ME2212 Unnamed: 1 Unnamed: 2   Unnamed: 3
# 0   Time      Force     Stress       Strain
# 1    sec          N      N/mm2            %
# 2      0       5.16  0.1285132            0
# 3   0.05     47.592    1.18531  0.007466666
# 4    0.1    132.681   3.304507   0.01485185

# %%
df.tail(4)
# Out:
#       ME2212 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 5246   262.2   11395.78   283.8194    38.8344
# 5247  262.25    4365.75   108.7319   38.83442
# 5248   262.3   1019.082   25.38091   38.83442
# 5249  262.34    212.748   5.298629   38.83442

# %%
df.shape
# Out:
# (5250, 4)

# %%
df.columns
# Out:
# Index(['ME2212', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
df.size
# Out:
# 21000

# %%
print(df[['Stress','Time']][1:50])
# Out:
#        Stress  Time
# 1    1.185310  0.05
# 2    3.304507  0.10
# 3    5.832855  0.15
# 4    8.279313  0.20
# 5   10.395450  0.25
# 6   11.880070  0.30
# 7   12.842880  0.35
# 8   13.792160  0.40
# 9   14.644600  0.45
# 10  15.356880  0.50
# 11  16.026720  0.55
# 12  16.704100  0.60
# 13  17.397030  0.65
# 14  18.136130  0.70
# 15  18.900780  0.75
# 16  19.662290  0.80
# 17  20.362920  0.85
# 18  20.982240  0.90
# 19  21.350150  0.95
# 20  21.383030  1.00
# 21  21.689590  1.05
# 22  22.612570  1.10
# 23  23.935800  1.15
# 24  25.428280  1.20
# 25  26.999650  1.25
# 26  28.557870  1.30
# 27  30.073880  1.35
# 28  31.564040  1.40
# 29  33.022660  1.45
# 30  34.440270  1.50
# 31  35.806690  1.55
# 32  37.152270  1.60
# 33  38.494930  1.65
# 34  39.828250  1.70
# 35  41.138200  1.75
# 36  42.396050  1.80
# 37  43.621710  1.85
# 38  44.839370  1.90
# 39  46.023190  1.95
# 40  47.147230  2.00
# 41  48.241390  2.05
# 42  49.319700  2.10
# 43  50.376120  2.15
# 44  51.386750  2.20
# ...

# %%
print(df.sort_values(['Stress'])[:20])
# Out:
#         Time     Force     Stress     Strain
# 0       0.00    5.1600   0.128513   0.000000
# 1       0.05   47.5920   1.185310   0.007467
# 2       0.10  132.6810   3.304507   0.014852
# 5247  262.34  212.7480   5.298629  38.834420
# 3       0.15  234.1980   5.832855   0.022215
# 4       0.20  332.4270   8.279313   0.029644
# 5       0.25  417.3930  10.395450   0.037096
# 6       0.30  477.0030  11.880070   0.044452
# 7       0.35  515.6610  12.842880   0.051844
# 8       0.40  553.7760  13.792160   0.059311
# 9       0.45  588.0030  14.644600   0.066711
# 10      0.50  616.6020  15.356880   0.074067
# 11      0.55  643.4970  16.026720   0.081489
# 12      0.60  670.6950  16.704100   0.088948
# 13      0.65  698.5170  17.397030   0.096319
# 14      0.70  728.1930  18.136130   0.103696
# 15      0.75  758.8950  18.900780   0.111141
# 16      0.80  789.4709  19.662290   0.118570
# 17      0.85  817.6020  20.362920   0.125933
# 18      0.90  842.4690  20.982240   0.133341

# %%
dg = df['Force'][4000:4500].value_counts()
print(dg)
# Out:
# Force
# 22709.82    3
# 22713.28    2
# 22713.01    2
# 22713.25    2
# 22712.74    2
#            ..
# 22639.29    1
# 22638.55    1
# 22638.60    1
# 22639.05    1
# 22645.34    1
# Name: count, Length: 477, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.plot(df["Stress"], df["Strain"])

plt.xlabel("Stress")
plt.ylabel("Strain")
plt.title("Stress vs Strain Graph")
plt.grid(True)

plt.show()
